# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !nvidia-smi
# Out:
# Tue Feb 18 14:12:38 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   46C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 921.5/921.5 kB 28.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 111.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 82.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 58.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 61.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/content/drive/MyDrive/data/data.yaml epochs=50 imgsz=640 batch=16 lr0=0.001
# Out:
# ...
# 100% 6.25M/6.25M [00:00<00:00, 333MB/s]
# Ultralytics 8.3.76 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO
model = YOLO('/content/runs/detect/train/weights/best.pt')

# %%
results = model('/content/drive/MyDrive/data/test/images/download.jpg')
results[0].plot()
# Out:
# image 1/1 /content/drive/MyDrive/data/test/images/download.jpg: 480x640 1 Nut, 1 Bolts, 37.3ms
# Speed: 4.5ms preprocess, 37.3ms inference, 145.7ms postprocess per image at shape (1, 3, 480, 640)
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
# ...

# %%
from google.colab import drive
import shutil
import os

# Mount Google Drive
drive.mount('/content/drive', force_remount=True)

# Define source and destination paths
source_path = '/content/runs'
destination_path = '/content/drive/MyDrive/data'

# Create the destination directory if it does not exist
os.makedirs(destination_path, exist_ok=True)

# Copy files and directories from source to destination
for item in os.listdir(source_path):
    s = os.path.join(source_path, item)
    d = os.path.join(destination_path, item)
    if os.path.isdir(s):
        shutil.copytree(s, d, dirs_exist_ok=True)
    else:
        shutil.copy2(s, d)
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/SkalskiP/yolov9.git
# %cd yolov9
# !pip install -r requirements.txt -q
# !pip install roboflow
# Out:
# fatal: destination path 'yolov9' already exists and is not an empty directory.
# /content/yolov9
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 64.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.1/83.1 kB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 19.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...

# %%
# !wget https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolo-c.pt
# !wget https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-e.pt
# !wget https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-c.pt
# !wget https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-e.pt
# Out:
# --2025-02-18 16:56:43--  https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolo-c.pt
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-02-18 16:56:44 ERROR 404: Not Found.
#
# --2025-02-18 16:56:44--  https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-e.pt
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !python /content/yolov9/train.py \
--batch 16 --epochs 50 --img 640 --device 0 --min-items 0 --close-mosaic 15 --lr0 0.001\
--data /content/drive/MyDrive/data/data.yaml \
--weights /content/gelan-c.pt \
--cfg /content/yolov9/panoptic/models/detect/gelan-c.yaml \
--hyp hyp.scratch-high.yaml
# Out:
# Traceback (most recent call last):
#   File "/content/yolov9/train.py", line 25, in <module>
#     import val as validate  # for end-of-epoch mAP
#     ^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/yolov9/val.py", line 17, in <module>
#     from models.common import DetectMultiBackend
# ModuleNotFoundError: No module named 'models'

# %%
import cv2
from ultralytics import YOLO
import numpy as np
from google.colab import files

# Load a pretrained YOLOv8n model
model = YOLO('/content/drive/MyDrive/data/yolov8/train/weights/best.pt')

# Open the video file
video_path = '/content/drive/MyDrive/data/video.mp4'
cap = cv2.VideoCapture(video_path)

if not cap.isOpened():
    print("Error opening video file")
    exit()

# Get video properties
fps = cap.get(cv2.CAP_PROP_FPS)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Define the codec and create VideoWriter object
output_path = '/content/output_video.mp4'
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Codec for mp4
out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

# Process video frames
frame_count = 0
try:
    while True:
        ret, frame = cap.read()
        if not ret:
            break

        # Run YOLOv8 inference
        results = model(frame)
        annotated_frame = results[0].plot()

        # Write the frame to the output video
        out.write(annotated_frame)
        frame_count += 1

        print(f"Processed frame {frame_count}", end='\r')

except KeyboardInterrupt:
    print("\nStopped by user")

finally:
    # Release resources
    cap.release()
    out.release()
    print(f"\nVideo processing completed. Processed {frame_count} frames.")

    # Download the video
    files.download(output_path)

print(f"Output video saved as {output_path}")
# Out:
# 0: 640x384 5 Nuts, 16.8ms
# Speed: 3.4ms preprocess, 16.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# Processed frame 1
# 0: 640x384 4 Nuts, 9.0ms
# Speed: 3.7ms preprocess, 9.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
# Processed frame 2
# 0: 640x384 3 Nuts, 7.8ms
# Speed: 3.4ms preprocess, 7.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# Processed frame 3
# 0: 640x384 5 Nuts, 7.8ms
# Speed: 3.7ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
# Processed frame 4
# 0: 640x384 5 Nuts, 12.7ms
# Speed: 3.1ms preprocess, 12.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
# Processed frame 5
# 0: 640x384 4 Nuts, 11.8ms
# Speed: 3.2ms preprocess, 11.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# Processed frame 6
# 0: 640x384 4 Nuts, 18.8ms
# ...
